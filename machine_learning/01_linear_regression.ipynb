# %%
# Linear Regression

# %%
# Import libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import r2_score,mean_squared_error

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# split the data into X and y
X=df[['total_bill']]
y=df['tip']

# %%
# scale the data 
scaler=MinMaxScaler()
X=scaler.fit_transform(X)

# %%
# remove the outliers by plotting boxplot
sns.boxplot(data=df,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
# remove the outliers
df=df[df['total_bill']<35]

# %%
# remove the outliers by plotting boxplot
sns.boxplot(data=df,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
# split the data into train and test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# call the model
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# print the intercept and coefficients
print("Intercept: ",model.intercept_)
print("Coefficients: ",model.coef_)
# Out:
# Intercept:  1.325883891600223
# Coefficients:  [4.62378144]

# %%
# prediction
y_pred=model.predict(X_test)

# %%
# plot the intercept and coefficients on test data
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,color='red')
plt.show()

# %%
# evaluate the model
print("R2 score: ",r2_score(y_test,y_pred))
print("MSE: ",mean_squared_error(y_test,y_pred))
print("RMSE: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score:  0.590689509858904
# MSE:  0.8213090642766288
# RMSE:  0.9062610353957786
